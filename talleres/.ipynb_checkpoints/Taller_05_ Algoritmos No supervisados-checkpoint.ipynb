# %% [markdown]
# <img src="../imgs/banner_IA.png"  width="1000px" height="200px">
#
# # Taller 5: Aprendizaje no supervizado.
#
# ## <span style="color:red"> Outline </span>
#
# 1. [Ejercicio 1. Image K-means](#eje1)
# 2. [Ejercicio 2. Variaedades de Trigo](#eje2)
# 3. [Ejercicio 3. AgglomerativeClustering](#eje3)
# 4. [Ejercicio 4. PCA + Nonsupervised](#eje4)
#
#
#
#
#
# #### <font style="color: red"> Esta práctica contiene 4 ejercicios <!-- ONLY IN NOTEBOOK -->
#
# <h2><span style="color:#FFF; background-color:#F00; font-weight:bold; padding:4px;">¡IMPORTANTE!</span> Ejecute esta celda para iniciar la actividad</h2>

# %%
# !chmod 777 empaquetar.sh run utils/*

# %%
import numpy as np
import pandas as pd
from skimage import io
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans 
from sklearn.cluster import DBSCAN

# %% [markdown]
# <h2><span style="color:#FFF; background-color:#F00; font-weight:bold; padding:4px;">¡IMPORTANTE!</span></h2><br><h2 style="margin-top:-10px;">Usted debe ejecutar <span style="color:#F00;">TODAS</span> las celdas de tipo <span style="color:#F00;">CODE</span>. De lo contrario, sus respuestas no serán procesadas correctamente.</h2>

# %% [markdown]
# ## Ejercicio 1 <a name="eje1"></a>
#
# Escriba una función que se le pase como argumento una imagen `img` y dos diferentes valores para el número de clusters *K*: ` k_c1, k_c2`. La función debe calcular dos diferentes k-means con numero de centroides: ` k_c1, k_c2`, respectivamente. Las caracteristicas **X** para el entrenamiento, son:
# - El componente de color R   (se asume que es el canal 0)
# - El componente de color G   (se asume que es el canal 1)
# - El componente de color B   (se asume que es el canal 2)
# - Los indices x de la imagen (valores en columnas)
# - Los indices y de la imagen (valores en filas)
#
# La función debe devolver el vector de etiquetas para el `kmeans(K_c1)`, el vector de etiquetas para el `kmeans(K_c2)` y sus respectivos estimadores ya entrenados.

# %%
def img_seg(img, k_c1, k_c2):
    import numpy as np
    from skimage import io
    import matplotlib.pyplot as plt
    from sklearn.cluster import KMeans 
    from sklearn.cluster import DBSCAN
    
    width, height = img.shape[0], img.shape[1]
    # Escriba aquí!

    
    return kmeans_c1.labels_, kmeans_c2.labels_, kmeans_c1, kmeans_c2

import urllib, inspect
src1 = urllib.quote_plus(inspect.getsource(img_seg))

# %% [markdown]
# Compruebe el resultado de la función con el siguiente código:

# %%
img = io.imread("../imgs/u.png")
width, height = img.shape[0], img.shape[1]
kmeansLabels_c1, kmeansLabels_c2, k1, k2  = img_seg(img, k_c1=2, k_c2=50)

plt.figure(figsize=(15,4))
plt.subplot(131);
plt.imshow(img)
plt.subplot(132);
plt.imshow(kmeansLabels_c1.reshape(width, height), cmap = plt.cm.get_cmap('prism'));
plt.subplot(133);
plt.imshow(kmeansLabels_c2.reshape(width, height), cmap = plt.cm.get_cmap('prism'));
# Out:
# (200, 200, 3) (200, 200) (200, 200)

# %% [markdown]
# #### <span style="color:#FFF; background-color:#080; font-weight:bold; padding:4px;">Importante</span> Evalue su respuesta.

# %%
# !./run CHECK_SOLUTION PS6_1 $src1

# %% [markdown]
# ##  Ejercicio 2 <a name="eje2"></a>
#
# El dataset `../data/seeds-less-rows.csv` presenta un conjunto de caracteristicas que identifican 3 diferentes variedades de trigo. Escriba una función que carge este *dataset*, separe los datos en etiquetas (clases de semillas) y caracteristicas **X** y realice un agrupamiento utilizando el algoritmo **DBSCAN** y todas las caracteristicas.
#
# La función debe:
# - **recibir** los parametros `epsilon`, `min_points` para fijar el algoritmo DBSCAN
# - **devolver** un arreglo **numérico** con los etiquetas de las semillas.
# - **devolver** el vector de etiquetas resultado del DBSCAN
# - **devolver** el respectivo estimador ya entrenado

# %%
def seeds_func(epsilon,min_points):
    import numpy as np
    import pandas as pd
    from sklearn.cluster import DBSCAN
    seeds_df = pd.read_csv('../data/seeds-less-rows.csv')
    
    # Escriba aquí!

    return class_int, DBS.labels_, DBS

import urllib, inspect
src2 = urllib.quote_plus(inspect.getsource(seeds_func))

# %% [markdown]
# Compruebe su código aquí.

# %%
seeds_df = pd.read_csv('../data/seeds-less-rows.csv')
X = seeds_df.values
seeds_df.head(5)
# Out:
#     area  perimeter  compactness  length  width  asymmetry_coefficient  \
# 0  14.88      14.57       0.8811   5.554  3.333                  1.018
# 1  14.69      14.49       0.8799   5.563  3.259                  3.586
# 2  14.03      14.16       0.8796   5.438  3.201                  1.717
# 3  13.99      13.83       0.9183   5.119  3.383                  5.234
# 4  14.11      14.26       0.8722   5.520  3.168                  2.688
#
#    groove_length grain_variety
# 0          4.956    Kama wheat
# 1          5.219    Kama wheat
# 2          5.001    Kama wheat
# 3          4.781    Kama wheat
# 4          5.219    Kama wheat

# %%
seeds_df = pd.read_csv('../data/seeds-less-rows.csv')
X = seeds_df.values
print X.shape
class_int, labels, DBS =seeds_func(epsilon= 1.2,min_points=3)

plt.figure(figsize=(15,4))
plt.subplot(321);
plt.scatter(X[:,0],X[:,1], c=class_int, cmap='rainbow') 
plt.subplot(322);
plt.scatter(X[:,0],X[:,1], c=labels, cmap='rainbow') 
plt.subplot(323);
plt.scatter(X[:,2],X[:,3], c=class_int, cmap='rainbow') 
plt.subplot(324);
plt.scatter(X[:,2],X[:,3], c=labels, cmap='rainbow') 
plt.subplot(325);
plt.scatter(X[:,3],X[:,4], c=class_int, cmap='rainbow') 
plt.subplot(326);
plt.scatter(X[:,3],X[:,4], c=labels, cmap='rainbow')
# Out:
# (42, 8)

# %% [markdown]
# #### <span style="color:#FFF; background-color:#080; font-weight:bold; padding:4px;">Importante</span> Evalue su respuesta

# %%
# !./run CHECK_SOLUTION PS6_2 $src2

# %% [markdown]
# ##  Ejercicio 3 <a name="eje3"></a>
#
# Existen muchos otros métodos para agrupar caracteristicas y aplicar el principio de algoritmos no supervisados. Escriba una función que explore el método de agrupamiento agrlometarivo (`AgglomerativeClustering`) sobre el dataset de las semillas de trigo. La función debe:
#
# - **recibir** los parametros `num_clusters` para fijar el algoritmo  `AgglomerativeClustering`
# - **devolver** un arreglo **numérico** con los etiquetas de las semillas.
# - **devolver** el vector de etiquetas resultado del `AgglomerativeClustering`
# - **devolver** el respectivo estimador ya entrenado

# %%
def ac_func(num_clusters):
    import numpy as np
    import pandas as pd
    from sklearn.cluster import AgglomerativeClustering
    seeds_df = pd.read_csv('../data/seeds-less-rows.csv')
   
    # Escriba aquí!

    return class_int, AC.labels_, AC

import urllib, inspect
src3 = urllib.quote_plus(inspect.getsource(ac_func))

# %%
seeds_df = pd.read_csv('../data/seeds-less-rows.csv')
X = seeds_df.values
print X.shape
class_int, labels, ac =ac_func(num_clusters=3)

plt.figure(figsize=(15,4))
plt.subplot(321);
plt.scatter(X[:,0],X[:,1], c=class_int, cmap='rainbow') 
plt.subplot(322);
plt.scatter(X[:,0],X[:,1], c=labels, cmap='rainbow') 
plt.subplot(323);
plt.scatter(X[:,2],X[:,3], c=class_int, cmap='rainbow') 
plt.subplot(324);
plt.scatter(X[:,2],X[:,3], c=labels, cmap='rainbow') 
plt.subplot(325);
plt.scatter(X[:,3],X[:,4], c=class_int, cmap='rainbow') 
plt.subplot(326);
plt.scatter(X[:,3],X[:,4], c=labels, cmap='rainbow')
# Out:
# (42, 8)

# %% [markdown]
# #### <span style="color:#FFF; background-color:#080; font-weight:bold; padding:4px;">Importante</span> Evalue su respuesta.

# %%
# !./run CHECK_SOLUTION PS6_3 $src3

# %% [markdown]
# ##  Ejercicio 4 <a name="eje4"></a>
#
# Cuando se tienen datos n-dimensionales, uno de los mas grandes desafios es su visualización para el análisis y la toma de decisiones. Un método empleado es la reducción n-dimensional usadando el PCA. También estos métodos nos permiten reducir el espacio de busqueda para los algoritmos de agrupamiento, pudiendo obtener mejores resultados.
#
# Implemente una función que reciba como parametros `epsilon, min_points` para el ajuste de un algoritmo DBSCAN. La función debe calcular los dos primeros componentes del PCA del dataset de las semillas de trigo: `'../data/seeds-less-rows.csv'`. Una vez obtenido los dos primeros componentes, transforme todas sus caracteristicas hacia estos dos principales componentes, es decir, ahora tendra unicamente dos caracteristicas. Utilizando estas *PCA-features* entrene un Kmeans(clusters =3) y un DBSCAN(epsilon, min_points).
#
# La función debe devolver:
# - Los datos con la reducción de la dimensionalidad aplicada, es decir, unicamente dos caracteristicas (PCA-features)
# - El vector de  etiquetas del kmeans
# - El vector de  etiquetas del DBSCAN
# - Los objetos entrenados KMEANS, BDSCAN y  PCA

# %% [markdown]
# Utilizar otro médo de clustering

# %%
def pca_and_clustering(epsilon,min_points):
    import numpy as np
    import pandas as pd
    from sklearn.decomposition import PCA
    from sklearn.cluster import DBSCAN
    from sklearn.cluster import KMeans

    
    seeds_df = pd.read_csv('../data/seeds-less-rows.csv')
    # Escriba aquí!
    
    
    return X, kmeans_c1.labels_, DBS.labels_, kmeans_c1, DBS, p
    
import urllib, inspect
src4 = urllib.quote_plus(inspect.getsource(pca_and_clustering))

# %% [markdown]
# Compruebe su función aquí:

# %%
X, kmeans_labels, DBS_labels, KMEANS_, DBS_, PCA_ =pca_and_clustering(epsilon= 1.2,min_points=3)

plt.figure(figsize=(15,4))
plt.subplot(131);
plt.scatter(X[:,0],X[:,1], c=class_int, cmap='rainbow') 
plt.subplot(132);
plt.scatter(X[:,0],X[:,1], c=kmeans_labels, cmap='rainbow') 
plt.subplot(133);
plt.scatter(X[:,0],X[:,1], c=DBS_labels, cmap='rainbow')

# %% [markdown]
# #### <span style="color:#FFF; background-color:#080; font-weight:bold; padding:4px;">Importante</span> Evalue su respuesta.

# %%
# !./run CHECK_SOLUTION PS6_4 $src4

# %% [markdown]
# ---
#
# #### <span style="color:#FFF; background-color:#080; font-weight:bold; padding:4px;">Importante</span> Pasos Finales.
#
# #### 1. Guarde los cambios del taller:

# %%
# %%javascript
# require(["base/js/namespace"],function(Jupyter) {
#     Jupyter.notebook.save_checkpoint();
# });

# %% [markdown]
# #### 2. Reemplace la variable con su código de estudiante

# %%
codigo = None

# %% [markdown]
# #### 3. Ejecute la siguiente selda y envíe el archivo comprimido

# %%
# !./empaquetar.sh $codigo

# %% [markdown]
# ---
# <img src="../imgs/bannerThanks.jpg" style="width:1000px;">
